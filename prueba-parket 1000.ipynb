# %% [markdown]
# <h1 style = "font-size:60px; font-family:Georgia ; font-weight : normal; color : #43464b; text-align: center;">
#     US Air Quality Analysis
# </h1>
#
# <p align="center">
#     <img src="https://cdn.pixabay.com/photo/2016/10/22/21/54/industry-1761801_960_720.jpg"
#          style = "display: block; margin-left: auto; margin-right: auto; width: 65%;"/>
# </p>
#
# # About the Air Quality Index
#
# The EPA developed the AQI, which reports levels of **ozone, particle pollution, and other common air
# pollutants** on the same scale. An AQI reading of 101 corresponds to a level that is above the national air
# quality standard—**the higher the AQI rating, the greater the health impact**.
# The AQI is divided into color-coded categories, and each category is identified by a simple informative
# descriptor. The descriptors are intended to convey information to the public about how air quality within
# each category relates to public health. **The table below defines the AQI categories**.
#
# Source: <a href="https://s3-us-west-1.amazonaws.com//files.airnowtech.org/airnow/docs/DailyDataFactSheet.pdf">
#         EPA</a>
#
# <img src="https://d2v9ipibika81v.cloudfront.net/uploads/sites/190/AQI-Table.png"
#      style = "display: block; margin-left: auto; margin-right: auto; width: 50%;"/>
#
# Source: <a href="https://kg.usembassy.gov/aqi-table/">
#         US Embassy</a>
#
#
# # Objective
#
# The objective of this notebook is to create an ML model to accurately **forecast AQI values in the USA up to 7 days in advance**. An acceptable model will have a **maximum RSME of 20 with an ideal value of less than 13**.
#
# <img src="https://miro.medium.com/max/966/1*lqDsPkfXPGen32Uem1PTNg.png"
#      style = "display: block;  width: 25%;"/>
#
# The **finished model will be embedded into *OpenAQI.io*** (not yet deployed) to provide users with accurate daily AQI forecasts.
#
#
#
# # Content
# <ul>
#     <li><strong>Read In Dataset</strong></li>
#     <li><strong>Sensor Locations</strong></li>
#     <li><strong>AQI Trends</strong></li>
#     <li><strong>Missing Measurements</strong></li>
#     <li><strong>Data Preprocessing</strong></li>
#     <li><strong>Model Definition</strong></li>
#     <li><strong>Model Evaluation</strong></li>
#     <li><strong>Conclusion</strong></li>
# </ul>

# %% [markdown]
# # Read In Dataset
#
# ### About Each Feature
# <ul>
# <li><strong>CBSA Code</strong> - The core-based statistical area (CBSA) code. CBSA = a U.S. geographic area defined by the Office of Management and Budget (OMB) that consists of one or more counties.</li>
# <li><strong>Date</strong> - The day of measurement.</li>
# <li><strong>AQI</strong> - The average air quality index (AQI) value for the day.</li>
# <li><strong>Category</strong> - The category of air quality ranging from "Good" to "Hazardous".</li>
# <li><strong>Defining Parameter</strong> - One of PM2.5 (particulate matter), PM10, Ozone, Carbon Monoxide, Sulfur Dioxide, or Nitrogen Dioxide which has the highest concentration.</li>
# <li><strong>Number of Sites Reporting</strong> - The number of stations used to make the data aggregation.</li>
# <li><strong>city_ascii</strong> - Name of the city where the measurement was taken.</li>
# <li><strong>state_id</strong> - Abbreviation of the state where the measurement was taken.</li>
# <li><strong>state_name</strong> - The state where the measurement was taken.</li>
# <li><strong>lat</strong> - The latitude where the measurement was taken.</li>
# <li><strong>lng</strong> - The longitude where the measurement was taken.</li>
# <li><strong>population</strong> - The population of the region where the measurement was taken.</li>
# <li><strong>density</strong> - The population per square kilometer where the measurement was taken.</li>
# <li><strong>timezone</strong> - The time zone of the region where the measurement was taken.</li>
# </ul>

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.10/site-packages (from ipython-autotime) (8.21.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (5.14.3)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->ipython-autotime) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython->ipython-autotime) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython->ipython-autotime) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython->ipython-autotime) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython->ipython-autotime) (1.16.0)
# Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl (7.0 kB)
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.3.2
# time: 265 µs (started: 2024-11-27 14:09:24 +00:00)

# %%
# !pip install parquet-tools
# Out:
# Collecting parquet-tools
#   Downloading parquet_tools-0.2.16-py3-none-any.whl.metadata (3.8 kB)
# Collecting boto3<2.0.0,>=1.34.11 (from parquet-tools)
#   Downloading boto3-1.35.70-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from parquet-tools) (0.4.6)
# Collecting halo<0.0.32,>=0.0.31 (from parquet-tools)
#   Downloading halo-0.0.31.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in /opt/conda/lib/python3.10/site-packages (from parquet-tools) (2.2.2)
# Requirement already satisfied: pyarrow in /opt/conda/lib/python3.10/site-packages (from parquet-tools) (16.1.0)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from parquet-tools) (0.9.0)
# Collecting thrift<0.17.0,>=0.16.0 (from parquet-tools)
#   Downloading thrift-0.16.0.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting botocore<1.36.0,>=1.35.70 (from boto3<2.0.0,>=1.34.11->parquet-tools)
#   Downloading botocore-1.35.70-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3<2.0.0,>=1.34.11->parquet-tools) (1.0.1)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<2.0.0,>=1.34.11->parquet-tools)
#   Downloading s3transfer-0.10.4-py3-none-any.whl.metadata (1.7 kB)
# Collecting log_symbols>=0.0.14 (from halo<0.0.32,>=0.0.31->parquet-tools)
#   Downloading log_symbols-0.0.14-py3-none-any.whl.metadata (523 bytes)
# Collecting spinners>=0.0.24 (from halo<0.0.32,>=0.0.31->parquet-tools)
#   Downloading spinners-0.0.24-py3-none-any.whl.metadata (576 bytes)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from halo<0.0.32,>=0.0.31->parquet-tools) (2.4.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from halo<0.0.32,>=0.0.31->parquet-tools) (1.16.0)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas<3.0.0,>=2.1.4->parquet-tools) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas<3.0.0,>=2.1.4->parquet-tools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3.0.0,>=2.1.4->parquet-tools) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas<3.0.0,>=2.1.4->parquet-tools) (2024.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.10/site-packages (from botocore<1.36.0,>=1.35.70->boto3<2.0.0,>=1.34.11->parquet-tools) (1.26.18)
# Downloading parquet_tools-0.2.16-py3-none-any.whl (31 kB)
# Downloading boto3-1.35.70-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 6.7 MB/s eta 0:00:00
# Downloading botocore-1.35.70-py3-none-any.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 97.6 MB/s eta 0:00:00:00:010:01
# Downloading log_symbols-0.0.14-py3-none-any.whl (3.1 kB)
# Downloading s3transfer-0.10.4-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 6.2 MB/s eta 0:00:00
# Downloading spinners-0.0.24-py3-none-any.whl (5.5 kB)
# Building wheels for collected packages: halo, thrift
#   Building wheel for halo (setup.py) ... done
#   Created wheel for halo: filename=halo-0.0.31-py3-none-any.whl size=11232 sha256=7bc67aa05070b122875a191fa9dd2f9193906aa100e3bf94ca6f0bbae4f26d6d
#   Stored in directory: /root/.cache/pip/wheels/5a/d9/8a/b4f14c44aba7c164d4379eca6f1dde59360050406b1edaec24
#   Building wheel for thrift (setup.py) ... done
#   Created wheel for thrift: filename=thrift-0.16.0-cp310-cp310-linux_x86_64.whl size=183292 sha256=c6dbd82fd51f5c45b1669ed8094e0fed2dd1dd8bd172183751113c645130dd1d
#   Stored in directory: /root/.cache/pip/wheels/52/f8/d2/acfd995e8247eb0cad372fa6a640a5fcf279ab2ed7c5c4490e
# Successfully built halo thrift
# Installing collected packages: spinners, thrift, log_symbols, halo, botocore, s3transfer, boto3, parquet-tools
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.35.23
#     Uninstalling botocore-1.35.23:
#       Successfully uninstalled botocore-1.35.23
#   Attempting uninstall: s3transfer
#     Found existing installation: s3transfer 0.6.2
#     Uninstalling s3transfer-0.6.2:
#       Successfully uninstalled s3transfer-0.6.2
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.26.100
#     Uninstalling boto3-1.26.100:
#       Successfully uninstalled boto3-1.26.100
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.15.1 requires botocore<1.35.24,>=1.35.16, but you have botocore 1.35.70 which is incompatible.
# Successfully installed boto3-1.35.70 botocore-1.35.70 halo-0.0.31 log_symbols-0.0.14 parquet-tools-0.2.16 s3transfer-0.10.4 spinners-0.0.24 thrift-0.16.0
# time: 20.1 s (started: 2024-11-27 14:09:24 +00:00)

# %%
# !parquet-tools
# Out:
# usage: parquet-tools [-h] {show,csv,inspect} ...
#
# parquet CLI tools
#
# positional arguments:
#   {show,csv,inspect}
#     show              Show human readable format. see `show -h`
#     csv               Cat csv style. see `csv -h`
#     inspect           Inspect parquet file. see `inspect -h`
#
# options:
#   -h, --help          show this help message and exit
# time: 1.88 s (started: 2024-11-27 14:09:44 +00:00)

# %%
#read in dataset
import pandas as pd
# Out:
# time: 323 ms (started: 2024-11-27 14:09:46 +00:00)

# %%
aqi_data = pd.read_csv('../input/us-air-quality-1980present/US_AQI.csv', index_col=0)
# Out:
# time: 13.8 s (started: 2024-11-27 14:09:46 +00:00)

# %%
#display a sample of the dataset
aqi_data.head()
# Out:
#    CBSA Code        Date  AQI Category Defining Parameter  \
# 0      10140  2022-01-01   21     Good              PM2.5
# 1      10140  2022-01-02   12     Good              PM2.5
# 2      10140  2022-01-03   18     Good              PM2.5
# 3      10140  2022-01-04   19     Good              PM2.5
# 4      10140  2022-01-05   17     Good              PM2.5
#
#    Number of Sites Reporting city_ascii state_id  state_name      lat  \
# 0                          2   Aberdeen       WA  Washington  46.9757
# 1                          2   Aberdeen       WA  Washington  46.9757
# 2                          2   Aberdeen       WA  Washington  46.9757
# 3                          2   Aberdeen       WA  Washington  46.9757
# 4                          2   Aberdeen       WA  Washington  46.9757
#
#         lng  population  density             timezone
# 0 -123.8094     16571.0    588.0  America/Los_Angeles
# 1 -123.8094     16571.0    588.0  America/Los_Angeles
# 2 -123.8094     16571.0    588.0  America/Los_Angeles
# 3 -123.8094     16571.0    588.0  America/Los_Angeles
# 4 -123.8094     16571.0    588.0  America/Los_Angeles
# time: 16.5 ms (started: 2024-11-27 14:10:00 +00:00)

# %%
#dataset summary statistics
aqi_data.describe()
# Out:
#           CBSA Code           AQI  Number of Sites Reporting           lat  \
# count  5.617325e+06  5.617325e+06               5.617325e+06  5.617325e+06
# mean   3.028285e+04  4.665572e+01               3.650273e+00  3.849210e+01
# std    1.142715e+04  3.570811e+01               5.092484e+00  5.595372e+00
# min    1.010000e+04  0.000000e+00               1.000000e+00  1.797430e+01
# 25%    2.010000e+04  3.000000e+01               1.000000e+00  3.494420e+01
# 50%    3.034000e+04  4.100000e+01               2.000000e+00  3.918860e+01
# 75%    4.042000e+04  5.400000e+01               4.000000e+00  4.211550e+01
# max    4.974000e+04  2.064600e+04               7.200000e+01  6.483530e+01
#
#                 lng    population       density
# count  5.617325e+06  5.617325e+06  5.617325e+06
# mean  -9.425695e+01  5.642292e+05  1.083637e+03
# std    1.678664e+01  1.537382e+06  1.013632e+03
# min   -1.593521e+02  1.903000e+03  4.000000e+00
# 25%   -1.069642e+02  2.843700e+04  5.250000e+02
# 50%   -8.893420e+01  1.225490e+05  8.340000e+02
# 75%   -8.154200e+01  3.913710e+05  1.255000e+03
# max   -6.606100e+01  1.868002e+07  1.076800e+04
# time: 1.17 s (started: 2024-11-27 14:10:00 +00:00)

# %%
aqi_data.to_parquet("/kaggle/working/US_AQI_PARK.parquet")
# Out:
# time: 4.4 s (started: 2024-11-27 14:10:01 +00:00)

# %%
# !parquet-tools inspect "/kaggle/working/US_AQI_PARK.parquet"
# Out:
# ############ file meta data ############
# created_by: parquet-cpp-arrow version 16.1.0
# num_columns: 15
# num_rows: 5617325
# num_row_groups: 6
# format_version: 2.6
# serialized_size: 15853
#
#
# ############ Columns ############
# CBSA Code
# Date
# AQI
# Category
# Defining Parameter
# Number of Sites Reporting
# city_ascii
# state_id
# state_name
# lat
# lng
# population
# density
# timezone
# __index_level_0__
#
# ############ Column(CBSA Code) ############
# name: CBSA Code
# path: CBSA Code
# max_definition_level: 1
# max_repetition_level: 0
# physical_type: INT64
# logical_type: None
# converted_type (legacy): NONE
# compression: SNAPPY (space_saved: 10%)
#
# ############ Column(Date) ############
# name: Date
# path: Date
# max_definition_level: 1
# max_repetition_level: 0
# physical_type: BYTE_ARRAY
# logical_type: String
# converted_type (legacy): UTF8
# compression: SNAPPY (space_saved: 80%)
#
# ############ Column(AQI) ############
# name: AQI
# path: AQI
# max_definition_level: 1
# max_repetition_level: 0
# physical_type: INT64
# logical_type: None
# converted_type (legacy): NONE
# compression: SNAPPY (space_saved: 0%)
#
# ############ Column(Category) ############
# name: Category
# path: Category
# max_definition_level: 1
# max_repetition_level: 0
# physical_type: BYTE_ARRAY
# logical_type: String
# converted_type (legacy): UTF8
# compression: SNAPPY (space_saved: 26%)
#
# ############ Column(Defining Parameter) ############
# name: Defining Parameter
# path: Defining Parameter
# max_definition_level: 1
# max_repetition_level: 0
# physical_type: BYTE_ARRAY
# logical_type: String
# converted_type (legacy): UTF8
# compression: SNAPPY (space_saved: 20%)
#
# ############ Column(Number of Sites Reporting) ############
# name: Number of Sites Reporting
# path: Number of Sites Reporting
# max_definition_level: 1
# max_repetition_level: 0
# physical_type: INT64
# logical_type: None
# converted_type (legacy): NONE
# compression: SNAPPY (space_saved: 53%)
#
# ############ Column(city_ascii) ############
# name: city_ascii
# path: city_ascii
# max_definition_level: 1
# max_repetition_level: 0
# physical_type: BYTE_ARRAY
# logical_type: String
# converted_type (legacy): UTF8
# compression: SNAPPY (space_saved: 9%)
#
# ############ Column(state_id) ############
# name: state_id
# path: state_id
# max_definition_level: 1
# max_repetition_level: 0
# physical_type: BYTE_ARRAY
# logical_type: String
# converted_type (legacy): UTF8
# compression: SNAPPY (space_saved: 19%)
#
# ############ Column(state_name) ############
# name: state_name
# path: state_name
# max_definition_level: 1
# max_repetition_level: 0
# physical_type: BYTE_ARRAY
# logical_type: String
# converted_type (legacy): UTF8
# compression: SNAPPY (space_saved: 19%)
#
# ############ Column(lat) ############
# name: lat
# path: lat
# max_definition_level: 1
# max_repetition_level: 0
# physical_type: DOUBLE
# logical_type: None
# converted_type (legacy): NONE
# compression: SNAPPY (space_saved: 1%)
#
# ############ Column(lng) ############
# name: lng
# path: lng
# max_definition_level: 1
# max_repetition_level: 0
# physical_type: DOUBLE
# logical_type: None
# converted_type (legacy): NONE
# compression: SNAPPY (space_saved: -0%)
#
# ############ Column(population) ############
# name: population
# path: population
# max_definition_level: 1
# max_repetition_level: 0
# physical_type: DOUBLE
# logical_type: None
# converted_type (legacy): NONE
# compression: SNAPPY (space_saved: 8%)
#
# ############ Column(density) ############
# name: density
# path: density
# max_definition_level: 1
# max_repetition_level: 0
# physical_type: DOUBLE
# logical_type: None
# converted_type (legacy): NONE
# compression: SNAPPY (space_saved: 11%)
#
# ############ Column(timezone) ############
# name: timezone
# path: timezone
# max_definition_level: 1
# max_repetition_level: 0
# physical_type: BYTE_ARRAY
# logical_type: String
# converted_type (legacy): UTF8
# compression: SNAPPY (space_saved: 25%)
#
# ############ Column(__index_level_0__) ############
# name: __index_level_0__
# path: __index_level_0__
# max_definition_level: 1
# max_repetition_level: 0
# physical_type: INT64
# logical_type: None
# converted_type (legacy): NONE
# compression: SNAPPY (space_saved: 48%)
#
# time: 1.77 s (started: 2024-11-27 14:10:06 +00:00)

# %%
aqi_data = pd.read_parquet("/kaggle/working/US_AQI_PARK.parquet")
# Out:
# time: 1.81 s (started: 2024-11-27 14:10:07 +00:00)

# %%
#display a sample of the dataset
aqi_data.head()
# Out:
#    CBSA Code        Date  AQI Category Defining Parameter  \
# 0      10140  2022-01-01   21     Good              PM2.5
# 1      10140  2022-01-02   12     Good              PM2.5
# 2      10140  2022-01-03   18     Good              PM2.5
# 3      10140  2022-01-04   19     Good              PM2.5
# 4      10140  2022-01-05   17     Good              PM2.5
#
#    Number of Sites Reporting city_ascii state_id  state_name      lat  \
# 0                          2   Aberdeen       WA  Washington  46.9757
# 1                          2   Aberdeen       WA  Washington  46.9757
# 2                          2   Aberdeen       WA  Washington  46.9757
# 3                          2   Aberdeen       WA  Washington  46.9757
# 4                          2   Aberdeen       WA  Washington  46.9757
#
#         lng  population  density             timezone
# 0 -123.8094     16571.0    588.0  America/Los_Angeles
# 1 -123.8094     16571.0    588.0  America/Los_Angeles
# 2 -123.8094     16571.0    588.0  America/Los_Angeles
# 3 -123.8094     16571.0    588.0  America/Los_Angeles
# 4 -123.8094     16571.0    588.0  America/Los_Angeles
# time: 12.4 ms (started: 2024-11-27 14:10:09 +00:00)

# %%
#dataset summary statistics
aqi_data.describe()
# Out:
#           CBSA Code           AQI  Number of Sites Reporting           lat  \
# count  5.617325e+06  5.617325e+06               5.617325e+06  5.617325e+06
# mean   3.028285e+04  4.665572e+01               3.650273e+00  3.849210e+01
# std    1.142715e+04  3.570811e+01               5.092484e+00  5.595372e+00
# min    1.010000e+04  0.000000e+00               1.000000e+00  1.797430e+01
# 25%    2.010000e+04  3.000000e+01               1.000000e+00  3.494420e+01
# 50%    3.034000e+04  4.100000e+01               2.000000e+00  3.918860e+01
# 75%    4.042000e+04  5.400000e+01               4.000000e+00  4.211550e+01
# max    4.974000e+04  2.064600e+04               7.200000e+01  6.483530e+01
#
#                 lng    population       density
# count  5.617325e+06  5.617325e+06  5.617325e+06
# mean  -9.425695e+01  5.642292e+05  1.083637e+03
# std    1.678664e+01  1.537382e+06  1.013632e+03
# min   -1.593521e+02  1.903000e+03  4.000000e+00
# 25%   -1.069642e+02  2.843700e+04  5.250000e+02
# 50%   -8.893420e+01  1.225490e+05  8.340000e+02
# 75%   -8.154200e+01  3.913710e+05  1.255000e+03
# max   -6.606100e+01  1.868002e+07  1.076800e+04
# time: 1.2 s (started: 2024-11-27 14:10:09 +00:00)

# %% [markdown]
# ### Takeaways
#
# <ul>
#     <li><strong>There are about 5.6 million rows.</strong></li>
#     <li><strong>There are 6 numeric features, 7 categoric features, and 1 date feature.</strong></li>
#     <li><strong>Each row is a measurement taken at a daily granularity.</strong></li>
# </ul>

# %% [markdown]
# # Sensor Locations

# %%
#library required for map plot below
# !pip install basemap
# Out:
# Collecting basemap
#   Downloading basemap-1.4.1-cp310-cp310-manylinux1_x86_64.whl.metadata (9.1 kB)
# Collecting basemap-data<1.4,>=1.3.2 (from basemap)
#   Downloading basemap_data-1.3.2-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pyshp<2.4,>=1.2 in /opt/conda/lib/python3.10/site-packages (from basemap) (2.3.1)
# Requirement already satisfied: matplotlib<3.9,>=1.5 in /opt/conda/lib/python3.10/site-packages (from basemap) (3.7.5)
# Requirement already satisfied: pyproj<3.7.0,>=1.9.3 in /opt/conda/lib/python3.10/site-packages (from basemap) (3.6.1)
# Requirement already satisfied: packaging<24.0,>=16.0 in /opt/conda/lib/python3.10/site-packages (from basemap) (21.3)
# Requirement already satisfied: numpy<1.27,>=1.21 in /opt/conda/lib/python3.10/site-packages (from basemap) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<3.9,>=1.5->basemap) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<3.9,>=1.5->basemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<3.9,>=1.5->basemap) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<3.9,>=1.5->basemap) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<3.9,>=1.5->basemap) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<3.9,>=1.5->basemap) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib<3.9,>=1.5->basemap) (2.9.0.post0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from pyproj<3.7.0,>=1.9.3->basemap) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<3.9,>=1.5->basemap) (1.16.0)
# Downloading basemap-1.4.1-cp310-cp310-manylinux1_x86_64.whl (935 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 936.0/936.0 kB 17.6 MB/s eta 0:00:00a 0:00:01
# Downloading basemap_data-1.3.2-py2.py3-none-any.whl (30.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 60.1 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: basemap-data, basemap
# Successfully installed basemap-1.4.1 basemap-data-1.3.2
# time: 9.53 s (started: 2024-11-27 14:10:10 +00:00)

# %%
#plots a map of sensor locations
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12,12))
m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution='c',lat_1=45.,lat_2=55,lat_0=50,lon_0=-107.)
# draw a boundary around the map, fill the background.
# this background will end up being the ocean color, since
# the continents will be drawn on top.
m.drawmapboundary(fill_color='aqua')
# fill continents, set lake color same as ocean color.
m.fillcontinents(color='coral',lake_color='aqua')
# draw parallels and meridians.
# label parallels on right and top
# meridians on bottom and left
parallels = np.arange(0.,81,10.)
# labels = [left,right,top,bottom]
m.drawparallels(parallels,labels=[False,True,True,False])
meridians = np.arange(10.,351.,20.)
m.drawmeridians(meridians,labels=[True,False,False,True])
# convert to map projection coords.
# Note that lon,lat can be scalars, lists or numpy arrays.
xpt,ypt = m(aqi_data.lng.values,aqi_data.lat.values)
m.scatter(xpt,ypt, color='black', s=0.1)  # plot a blue dot there
plt.gcf().text(0.2, 0.85, 'Location of Air Quality Measurements', 
               {'size': 25, 'weight': 'bold'})
plt.show()
# Out:
# time: 4.15 s (started: 2024-11-27 14:10:20 +00:00)

# %% [markdown]
# ### Takeaways
#
# <ul>
#     <li><strong>Sensors are loacated only within the US or US territories.</strong></li>
#     <li><strong>Alaska, Hawaii, and Puerto Rico are included in this dataset.</strong></li>
#     <li><strong>Sensor locations are most sparse in the mid-west region of the US.</strong></li>
# </ul>

# %% [markdown]
# # AQI Trends
#
# <ul>
#     <li><strong>AQI Trends - US Average</strong></li>
#     <li><strong>AQI Trends - State Averages</strong></li>
#     <li><strong>AQI Trends - Site Measurements</strong></li>
# </ul>

# %%
# Sets pathces for different aqi levels
from matplotlib.patches import Patch
from copy import copy

GOOD = plt.Rectangle((-1_000,0), 17_500, 50, fc='green',ec="green", alpha=0.25)
MODERATE = plt.Rectangle((-1_000,50), 17_500, 50, fc='yellow',ec="yellow", alpha=0.25)
UNHEALTHY_FOR_SENSITIVE = plt.Rectangle((-1_000,100), 17_500, 50,
                                                  fc='orange',ec="orange", alpha=0.25)
UNHEALTHY = plt.Rectangle((-1_000,150), 17_500, 50, fc='red',ec="red", alpha=0.25)
VERY_UNHEALTHY = plt.Rectangle((-1_000,200), 17_500, 100, fc='purple',ec="purple", alpha=0.25)
HAZARDOUS = plt.Rectangle((-1_000,300), 17_500, 200, fc='maroon',ec="maroon", alpha=0.25)
# Out:
# time: 1.99 ms (started: 2024-11-27 14:10:24 +00:00)

# %% [markdown]
# ## AQI Trends - US Average

# %%
#plots time series of US average AQI
aqi_all_usa = aqi_data.groupby('Date').AQI.mean().loc[:'2022-01-01']

aqi_all_usa.plot(figsize=(12,4), color='black', alpha=0.75)
plt.title('USA Average AQI 1980-2022', {'size': 25, 'weight': 'bold'})

# adds color patches 
plt.gca().add_patch(copy(GOOD))
plt.gca().add_patch(copy(MODERATE))
plt.gca().add_patch(copy(UNHEALTHY_FOR_SENSITIVE))
plt.gca().add_patch(copy(UNHEALTHY))
plt.gca().add_patch(copy(VERY_UNHEALTHY))
plt.gca().add_patch(copy(HAZARDOUS))

plt.xlabel('')
plt.ylabel('AQI', {'size': 14, 'weight': 'bold'})

plt.ylim(0, 500)

#Sets up legend
legend_elements = [
    Patch(facecolor='green', edgecolor='black', alpha=0.5, label='Good'),
    Patch(facecolor='yellow', edgecolor='black', alpha=0.5, label='Moderate'),
    Patch(facecolor='orange', edgecolor='black', alpha=0.5, label='Unhealthy for Sensitive Groups'),
    Patch(facecolor='red', edgecolor='black', alpha=0.5, label='Unhealthy'),
    Patch(facecolor='purple', edgecolor='black', alpha=0.5, label='Very Unhealthy'),
    Patch(facecolor='maroon', edgecolor='black', alpha=0.5, label='Hazardous'),
                  ]


legend = plt.legend(handles=legend_elements)
legend.set_title("AQI Category", prop = {'size':12, 'weight': 'bold'})

#displays the plot
plt.show()
# Out:
# time: 822 ms (started: 2024-11-27 14:10:24 +00:00)

# %%
#plots time series statistics
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose

#decomposes time series seasonality, trend, and residual
seasonal_decompose(aqi_all_usa.values, model='multiplicative', period=365).plot()
plt.gcf().set_figheight(8)
plt.gcf().set_figwidth(12)
plt.show()

#plots partial autocorrelation function
plot_pacf(aqi_all_usa.values, lags=365)
plt.gcf().set_figheight(4)
plt.gcf().set_figwidth(12)
plt.show()

#plots autocorrelation function
plot_acf(aqi_all_usa.values, lags=365)
plt.gcf().set_figheight(4)
plt.gcf().set_figwidth(12)
plt.show()
# Out:
# time: 4.4 s (started: 2024-11-27 14:10:25 +00:00)

# %% [markdown]
# #### How to Read the Above Plots
#
# **Observed** - Actual AQI values
#
# **Trend** - Yearly trend of AQI values extracted from *Observed*
#
# **Seasonality** - Yearly seasonality of AQI values extracted from *Observed*
#
# **Residual** - Left over error residuals when *Trend* and *Seasonality* are removed from *Observed*
#
# **Partial Autocorrelation** - The direct correlation between timestep *x* and timestep *x-n* where n is the value of the x-axis and the correlation value is the y-axis
#
# **Autocorrelation** - A combination of the direct and indirect correlation between timestep *x* and timestep *x-n* where n is the value of the x-axis and the correlation value is the y-axis

# %% [markdown]
# ## AQI Trends - State Averages

# %%
#function to plot aqi given an area
def make_aqi_by_area_plot(df, area, clip_dates=True):
    if clip_dates:
        data = df.unstack().loc[area, :"2022-01-01"]
    else:
        data = df.unstack().loc[area]
        
    data.plot(figsize=(12,4), color='black', alpha=0.75)
    
    
    plt.title(f'{area} Average AQI 1980-2022', {'size': 25, 'weight': 'bold'})

    # adds color patches 
    plt.gca().add_patch(copy(GOOD))
    plt.gca().add_patch(copy(MODERATE))
    plt.gca().add_patch(copy(UNHEALTHY_FOR_SENSITIVE))
    plt.gca().add_patch(copy(UNHEALTHY))
    plt.gca().add_patch(copy(VERY_UNHEALTHY))
    plt.gca().add_patch(copy(HAZARDOUS))

    plt.xlabel('')
    plt.ylabel('AQI', {'size': 14, 'weight': 'bold'})
    
    plt.ylim(0, 500)
    
    #sets up legend
    legend_elements = [
        Patch(facecolor='green', edgecolor='black', alpha=0.5, label='Good'),
        Patch(facecolor='yellow', edgecolor='black', alpha=0.5, label='Moderate'),
        Patch(facecolor='orange', edgecolor='black', alpha=0.5, label='Unhealthy for Sensitive Groups'),
        Patch(facecolor='red', edgecolor='black', alpha=0.5, label='Unhealthy'),
        Patch(facecolor='purple', edgecolor='black', alpha=0.5, label='Very Unhealthy'),
        Patch(facecolor='maroon', edgecolor='black', alpha=0.5, label='Hazardous'),
                      ]

    legend = plt.legend(handles=legend_elements)
    legend.set_title("AQI Category", prop = {'size':12, 'weight': 'bold'})
    
    #display plot
    plt.show()
# Out:
# time: 1.76 ms (started: 2024-11-27 14:10:29 +00:00)

# %%
#Makes dataframe of US State AQI averages
aqi_by_state = aqi_data.groupby(['state_id', 'Date']).AQI.mean()

#plots AQI averages for each state listed
for state in ['CA', 'TX', 'FL', 'NY']:
    make_aqi_by_area_plot(aqi_by_state, state)
# Out:
# time: 2.77 s (started: 2024-11-27 14:10:29 +00:00)

# %% [markdown]
# ## AQI Trends - Site Measurements

# %%
#Makes dataframe of AQI by cbsa code
aqi_by_cbsa = aqi_data.groupby(['CBSA Code', 'Date']).AQI.mean()

#plots AQI for each cbsa code listed
for cbsa in [36540, 40140, 19380]:
    make_aqi_by_area_plot(aqi_by_cbsa, cbsa, clip_dates=False)
# Out:
# time: 4.92 s (started: 2024-11-27 14:10:32 +00:00)

# %% [markdown]
# ### Takeaways
#
# <ul>
#     <li><strong>AQI values and standard deviation are decreasing each year across the USA.</strong></li>
#     <li><strong>There is a strong yearly seasonality to the AQI values.</strong></li>
#     <li><strong>The current daily AQI value has a high direct correlation to the past 30 or so previous days.</strong></li>
#     <li><strong>There are a few extreme AQI values in the California region - likely due to wildfires.</strong></li>
# </ul>

# %% [markdown]
# # Missing Measurements

# %%
#This cell plots the first measurement -> last measurement for each sensor
from datetime import timedelta, datetime

#group data by cbsa and get the first + last measurement
cbsa_grp = aqi_data.groupby('CBSA Code').agg({'Date': ['min', 'max', 'count']})

mins = pd.to_datetime(cbsa_grp[('Date',   'min')])
maxs = pd.to_datetime(cbsa_grp[('Date',   'max')])
min_date = mins.min()

a = mins - min_date
b = maxs - min_date
a = a.dt.days
b = b.dt.days


cbsa_grp['Start'] = a
cbsa_grp['End'] = b
                    
cbsa_grp = cbsa_grp.sort_values(['Start', 'End'], ascending=True)


plt.figure(figsize=(20,10))
plt.hlines(range(671), xmin=cbsa_grp['Start'],
            xmax=cbsa_grp['End'], color='black', 
            alpha=0.5)
plt.plot(cbsa_grp['Start'], range(671), "o", label='First Measurement')
plt.plot(cbsa_grp['End'], range(671), "o", label='Last Measurement')

plt.yticks([671, int(671*0.75), int(671*0.5), int(671*0.25), 0],
           ['100%', '75%', '50%', '25%', '0%'])
plt.xticks(range(0,16_000, 2_000), 
           [str(min_date + timedelta(days=days))[:10] for days in range(0,16_000, 2_000)])
plt.ylabel('Percentage of Sites', {'size': 14, 'weight': 'bold'})

plt.legend(fontsize=20)
plt.grid(axis='both', lw=2, linestyle='-.')

plt.title('Gaps In Measurement For Each CBSA', {'size': 25, 'weight': 'bold'})

plt.show()
# Out:
# time: 1.77 s (started: 2024-11-27 14:10:37 +00:00)

# %%
#This cell plots the number of missing measurements for each sensor
plt.figure(figsize=(8, 8))

plt.barh(range(671),
         ((cbsa_grp['End'] - cbsa_grp['Start']) - cbsa_grp[('Date', 'count')]+1).sort_values().values,
        color='purple', alpha=0.7)

plt.yticks([671, int(671*0.75), int(671*0.5), int(671*0.25), 0],
           ['100%', '75%', '50%', '25%', '0%'])
plt.ylabel('Percentage of Sites', {'size': 14, 'weight': 'bold'})
plt.xlabel('Number of Days with Missing Values', {'size': 14, 'weight': 'bold'})

plt.grid(axis='both', lw=1, linestyle='-.')
plt.title('Number Of Missing Measurements For Each CBSA', {'size': 25, 'weight': 'bold'})
plt.show()
# Out:
# time: 1.01 s (started: 2024-11-27 14:10:39 +00:00)

# %% [markdown]
# ### Takeaways
#
# <ul>
#     <li><strong>About 30% of all sensors start measurements in 1980.</strong></li>
#     <li><strong>Almost 100% of sensors have a first measurement before 2010.</strong></li>
#     <li><strong>Almost 100% of sensors have a last measurement in 2022.</strong></li>
#     <li><strong>About 50% of sensors have less than 2,000 missing values (=5.5yrs).</strong></li>
# </ul>

# %% [markdown]
# # Data Preprocessing
#
# **1. Extract Timeseries Windows**
#
# For each sensor, if there is a window of 37 consecutive measurements (no missing values) -> append to data array
#
# **2. Scale Data**
#
# Data will be scaled to have a mean of 0 and standard deviation of 1
#
# **3. Split Into X and y**
#
# The first 30 measurements will be X and the last 7 will be y

# %%
#plots the split of training, validation, and training data

aqi_all_usa.plot(figsize=(12,4), color='black', alpha=0.75)
plt.title('Train/Validation/Test Set Split', {'size': 25, 'weight': 'bold'})

# adds color patches 
historic = plt.Rectangle((-1_000,0), 12_688, 500, fc='red',ec="red", alpha=0.25)
train = plt.Rectangle((11_688,0), 3_287, 500, fc='green',ec="green", alpha=0.25)
validation = plt.Rectangle((14_975,0), 188, 500, fc='orange',ec="orange", alpha=0.25)
test = plt.Rectangle((15_163,0), 17_500, 500, fc='blue',ec="blue", alpha=0.25)


plt.gca().add_patch(historic)
plt.gca().add_patch(train)
plt.gca().add_patch(validation)
plt.gca().add_patch(test)


plt.xlabel('')
plt.ylabel('AQI', {'size': 14, 'weight': 'bold'})

plt.ylim(0, 500)
plt.xlim(0, 15_350)

#Sets up legend

legend_elements = [
    Patch(facecolor='red', edgecolor='black', alpha=0.5, label='Historic Data (Not Used)'),
    Patch(facecolor='green', edgecolor='black', alpha=0.5, label='Training Set'),
    Patch(facecolor='orange', edgecolor='black', alpha=0.5, label='Validation Set'),
    Patch(facecolor='blue', edgecolor='black', alpha=0.5, label='Test Set')
                  ]


legend = plt.legend(handles=legend_elements)
legend.set_title("Data Set", prop = {'size':12, 'weight': 'bold'})

#displays the plot
plt.show()
# Out:
# time: 330 ms (started: 2024-11-27 14:10:40 +00:00)

# %%
from concurrent.futures import ThreadPoolExecutor
import threading
import pandas as pd
import numpy as np
from datetime import timedelta

# Inicializar listas globales
train_windows = []
test_windows = []
val_windows = []

# Función que procesa cada índice de cbsa_grp
def process_cbsa(i):
    local_train_windows = []
    local_test_windows = []
    local_val_windows = []
    
    cbsa = cbsa_grp.index[i]
    temp_df = aqi_data[aqi_data['CBSA Code'] == cbsa]
    temp_df.index = pd.to_datetime(temp_df['Date'])

    temp_df = temp_df.loc[:, 'AQI']  # Obtener valores de AQI

    start_date = temp_df.index.min()  # Primera medición
    end_date = temp_df.index.max()    # Última medición

    # Rellenar fechas faltantes con np.NaN
    new_index = pd.date_range(start_date, end_date, freq='D')
    filler_aqi = [np.NaN for _ in new_index]

    filler = pd.DataFrame({'Fill_AQI': filler_aqi}, index=new_index)
    temp = filler.join(temp_df)

    aqi_vals = temp.AQI.values
    ix = 0

    # Procesar ventanas de 37 días
    while ix < aqi_vals.shape[0] - 37:
        window = aqi_vals[ix: ix + 37]

        # Validar ventanas sin valores faltantes
        if (np.isnan(window).sum() == 0) and ((start_date + timedelta(days=ix)).year > 2011):
            curr_time = start_date + timedelta(days=ix)

            # Clasificar datos en conjuntos
            if curr_time.year == 2021:
                if curr_time.month > 6:
                    local_test_windows.append([w if w <= 500 else 500 for w in window])
                else:
                    local_val_windows.append([w if w <= 500 else 500 for w in window])
            else:
                local_train_windows.append([w if w <= 500 else 500 for w in window])
        ix += 1

    return local_train_windows, local_val_windows, local_test_windows

# Función que incluye el registro del hilo actual
def process_cbsa_debug(i):
    print(f"Procesando índice {i} en hilo: {threading.current_thread().name}")
    return process_cbsa(i)

# Ejecutar paralelización
num_threads = 16
with ThreadPoolExecutor(max_workers=num_threads) as executor:
    results = list(executor.map(process_cbsa_debug, range(cbsa_grp.shape[0])))

# Consolidar resultados
for train, val, test in results:
    train_windows.extend(train)
    val_windows.extend(val)
    test_windows.extend(test)

# Mostrar resultados
print('NUMBER OF TRAINING DATA SAMPLES:', len(train_windows))
print('NUMBER OF VALIDATION DATA SAMPLES:', len(val_windows))
print('NUMBER OF TESTING DATA SAMPLES:', len(test_windows))
# Out:
# Procesando índice 0 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 1 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 2 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 3 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 4 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 5 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 6 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 7 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 8 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 9 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 10 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 11 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 12 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 13 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 14 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 15 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 16 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 17 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 18 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 19 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 20 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 21 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 22 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 23 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 24 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 25 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 26 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 27 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 28 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 29 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 30 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 31 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 32 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 33 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 34 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 35 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 36 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 37 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 38 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 39 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 40 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 41 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 42 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 43 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 44 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 45 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 46 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 47 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 48 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 49 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 50 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 51 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 52 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 53 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 54 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 55 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 56 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 57 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 58 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 59 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 60 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 61 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 62 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 63 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 64 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 65 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 66 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 67 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 68 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 69 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 70 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 71 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 72 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 73 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 74 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 75 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 76 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 77 en hilo: ThreadPoolExecutor-1_10Procesando índice 78 en hilo: ThreadPoolExecutor-1_8
#
# Procesando índice 79 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 80 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 81 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 82 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 83 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 84 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 85 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 86 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 87 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 88 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 89 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 90 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 91 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 92 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 93 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 94 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 95 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 96 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 97 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 98 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 99 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 100 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 101 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 102 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 103 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 104 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 105 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 106 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 107 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 108 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 109 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 110 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 111 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 112 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 113 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 114 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 115 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 116 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 117 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 118 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 119 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 120 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 121 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 122 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 123 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 124 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 125 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 126 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 127 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 128 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 129 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 130 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 131 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 132 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 133 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 134 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 135 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 136 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 137 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 138 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 139 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 140 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 141 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 142 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 143 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 144 en hilo: ThreadPoolExecutor-1_15Procesando índice 145 en hilo: ThreadPoolExecutor-1_10
#
# Procesando índice 146 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 147 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 148 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 149 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 150 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 151 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 152 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 153 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 154 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 155 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 156 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 157 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 158 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 159 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 160 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 161 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 162 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 163 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 164 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 165 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 166 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 167 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 168 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 169 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 170 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 171 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 172 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 173 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 174 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 175 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 176 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 177 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 178 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 179 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 180 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 181 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 182 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 183 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 184 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 185 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 186 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 187 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 188 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 189 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 190 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 191 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 192 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 193 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 194 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 195 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 196 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 197 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 198 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 199 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 201 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 200 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 202 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 203 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 204 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 205 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 206 en hilo: ThreadPoolExecutor-1_3Procesando índice 207 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 208 en hilo: ThreadPoolExecutor-1_12
#
# Procesando índice 209 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 210 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 211 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 212 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 213 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 214 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 215 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 216 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 217 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 218 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 219 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 220 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 221 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 222 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 223 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 224 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 225 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 226 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 227 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 228 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 229 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 230 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 231 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 232 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 233 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 234 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 235 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 236 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 237 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 238 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 239 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 240 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 241 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 242 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 243 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 244 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 245 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 246 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 247 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 248 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 249 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 250 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 251 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 252 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 253 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 254 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 255 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 256 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 257 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 258 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 259 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 260 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 261 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 262 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 263 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 265 en hilo: ThreadPoolExecutor-1_4Procesando índice 266 en hilo: ThreadPoolExecutor-1_0
#
# Procesando índice 264 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 267 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 268 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 269 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 270 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 271 en hilo: ThreadPoolExecutor-1_10Procesando índice 272 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 273 en hilo: ThreadPoolExecutor-1_7
#
# Procesando índice 274 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 275 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 276 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 277 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 278 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 279 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 280 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 281 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 282 en hilo: ThreadPoolExecutor-1_0Procesando índice 283 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 284 en hilo: ThreadPoolExecutor-1_9
#
# Procesando índice 285 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 286 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 287 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 288 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 289 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 290 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 291 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 292 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 293 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 294 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 295 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 296 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 297 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 298 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 299 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 300 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 301 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 302 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 303 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 304 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 305 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 306 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 307 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 308 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 309 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 310 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 311 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 312 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 313 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 314 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 315 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 316 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 317 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 318 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 319 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 320 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 321 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 322 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 323 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 324 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 325 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 326 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 327 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 328 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 329 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 330 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 331 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 332 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 333 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 334 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 335 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 336 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 337 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 338 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 339 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 340 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 341 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 342 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 343 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 344 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 345 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 346 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 347 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 348 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 349 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 350 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 351 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 352 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 353 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 354 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 355 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 356 en hilo: ThreadPoolExecutor-1_11Procesando índice 357 en hilo: ThreadPoolExecutor-1_13
#
# Procesando índice 358 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 359 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 360 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 361 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 362 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 363 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 364 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 365 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 366 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 367 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 368 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 369 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 370 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 371 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 372 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 373 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 374 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 375 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 376 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 377 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 378 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 379 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 380 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 381 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 382 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 383 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 384 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 385 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 386 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 387 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 388 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 389 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 390 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 391 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 392 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 393 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 394 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 395 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 396 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 397 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 398 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 399 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 400 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 401 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 402 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 403 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 404 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 405 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 406 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 407 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 408 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 409 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 410 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 411 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 412 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 413 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 414 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 415 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 416 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 417 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 418 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 419 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 420 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 421 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 422 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 423 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 424 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 425 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 426 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 427 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 428 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 429 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 430 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 431 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 432 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 433 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 434 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 435 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 436 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 437 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 438 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 439 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 440 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 441 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 442 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 443 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 444 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 445 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 446 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 447 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 448 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 449 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 450 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 451 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 452 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 453 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 454 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 455 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 456 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 457 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 458 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 459 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 460 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 461 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 462 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 463 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 464 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 465 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 466 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 467 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 468 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 469 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 470 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 471 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 472 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 473 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 474 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 475 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 476 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 477 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 478 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 479 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 480 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 481 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 482 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 483 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 484 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 485 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 486 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 487 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 488 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 489 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 490 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 491 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 492 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 493 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 494 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 495 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 496 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 497 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 498 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 499 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 500 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 501 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 502 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 503 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 504 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 505 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 506 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 507 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 508 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 509 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 510 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 511 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 512 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 513 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 514 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 515 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 516 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 517 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 518 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 519 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 520 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 521 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 522 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 523 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 524 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 525 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 526 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 527 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 528 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 529 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 530 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 531 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 532 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 533 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 534 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 535 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 536 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 537 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 538 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 539 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 540 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 541 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 542 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 543 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 544 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 545 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 546 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 547 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 548 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 549 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 550 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 551 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 552 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 553 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 554 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 555 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 556 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 557 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 558 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 559 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 560 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 561 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 562 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 563 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 564 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 565 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 566 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 567 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 568 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 569 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 570 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 571 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 572 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 573 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 574 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 575 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 576 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 577 en hilo: ThreadPoolExecutor-1_6Procesando índice 578 en hilo: ThreadPoolExecutor-1_2
#
# Procesando índice 579 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 580 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 581 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 582 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 583 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 584 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 585 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 586 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 587 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 588 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 589 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 590 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 591 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 592 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 593 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 594 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 595 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 596 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 597 en hilo: ThreadPoolExecutor-1_5Procesando índice 598 en hilo: ThreadPoolExecutor-1_15
#
# Procesando índice 599 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 600 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 601 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 602 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 603 en hilo: ThreadPoolExecutor-1_1Procesando índice 604 en hilo: ThreadPoolExecutor-1_12
#
# Procesando índice 605 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 606 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 607 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 608 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 609 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 610 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 611 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 612 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 613 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 614 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 615 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 616 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 617 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 618 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 619 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 620 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 621 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 622 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 623 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 624 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 625 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 626 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 627 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 628 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 629 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 630 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 631 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 632 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 633 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 634 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 635 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 636 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 637 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 638 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 639 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 640 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 641 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 642 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 643 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 644 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 645 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 646 en hilo: ThreadPoolExecutor-1_14Procesando índice 647 en hilo: ThreadPoolExecutor-1_13
#
# Procesando índice 648 en hilo: ThreadPoolExecutor-1_7
# Procesando índice 649 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 650 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 651 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 652 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 653 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 654 en hilo: ThreadPoolExecutor-1_8
# Procesando índice 655 en hilo: ThreadPoolExecutor-1_2
# Procesando índice 656 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 657 en hilo: ThreadPoolExecutor-1_10
# Procesando índice 658 en hilo: ThreadPoolExecutor-1_6
# Procesando índice 659 en hilo: ThreadPoolExecutor-1_4
# Procesando índice 660 en hilo: ThreadPoolExecutor-1_3
# Procesando índice 661 en hilo: ThreadPoolExecutor-1_12
# Procesando índice 662 en hilo: ThreadPoolExecutor-1_13
# Procesando índice 663 en hilo: ThreadPoolExecutor-1_14
# Procesando índice 664 en hilo: ThreadPoolExecutor-1_1
# Procesando índice 665 en hilo: ThreadPoolExecutor-1_9
# Procesando índice 666 en hilo: ThreadPoolExecutor-1_5
# Procesando índice 667 en hilo: ThreadPoolExecutor-1_11
# Procesando índice 668 en hilo: ThreadPoolExecutor-1_0
# Procesando índice 669 en hilo: ThreadPoolExecutor-1_15
# Procesando índice 670 en hilo: ThreadPoolExecutor-1_7
# NUMBER OF TRAINING DATA SAMPLES: 1313378
# NUMBER OF VALIDATION DATA SAMPLES: 74137
# NUMBER OF TESTING DATA SAMPLES: 69366
# time: 1min 31s (started: 2024-11-27 14:10:40 +00:00)

# %%
#from sklearn.preprocessing import StandardScaler

#train_meta_data = np.array(train_meta_data)
#test_meta_data = np.array(test_meta_data)
#val_meta_data = np.array(val_meta_data)

#ss_meta = StandardScaler()
#train_meta_data = ss_meta.fit_transform(train_meta_data)
#test_meta_data = ss_meta.transform(test_meta_data)
#val_meta_data = ss_meta.transform(val_meta_data)

# 2. Scale Data
aqi_mean = np.array(train_windows).mean() #mean of training set
aqi_std = np.array(train_windows).std() #standard deviation of training set

#scales data
train_windows = (np.array(train_windows) - aqi_mean) / aqi_std
test_windows = (np.array(test_windows) - aqi_mean) / aqi_std
val_windows = (np.array(val_windows) - aqi_mean) / aqi_std


# 3. Split Into X and y
train_X = train_windows[:, :-7]
train_X = train_X.reshape(train_X.shape[0], 30, 1)
train_y = train_windows[:, -7:]

test_X = test_windows[:, :-7]
test_X = test_X.reshape(test_X.shape[0], 30, 1)
test_y = test_windows[:, -7:]

val_X = val_windows[:, :-7]
val_X = val_X.reshape(val_X.shape[0], 30, 1)
val_y = val_windows[:, -7:]


#display a sample of data
print("SAMPLE OF PREPROCCESED DATA SET")
print("======================================")
print("X:", train_X[0])
print("y:", train_y[0])
# Out:
# SAMPLE OF PREPROCCESED DATA SET
# ======================================
# X: [[-0.74127998]
#  [-0.69626552]
#  [-0.60623662]
#  [-0.87632334]
#  [-0.96635224]
#  [-1.23643896]
#  [-0.56122217]
#  [-0.78629443]
#  [-0.78629443]
#  [-0.87632334]
#  [-0.83130888]
#  [-0.78629443]
#  [-1.1013956 ]
#  [-0.60623662]
#  [-0.47119326]
#  [-0.78629443]
#  [-0.87632334]
#  [-0.69626552]
#  [-0.83130888]
#  [-0.60623662]
#  [-0.74127998]
#  [-0.56122217]
#  [-0.60623662]
#  [-0.96635224]
#  [-0.87632334]
#  [-1.23643896]
#  [-0.74127998]
#  [-0.51620771]
#  [-0.47119326]
#  [-0.47119326]]
# y: [-0.3361499  -0.47119326 -0.74127998 -0.74127998 -0.56122217 -0.60623662
#  -0.24612099]
# time: 9.36 s (started: 2024-11-27 14:12:12 +00:00)

# %%
aqi_mean
# Out:
# 43.467599332161555
# time: 2.67 ms (started: 2024-11-27 14:12:21 +00:00)

# %%
aqi_std
# Out:
# 22.21508718833175
# time: 7.23 ms (started: 2024-11-27 14:12:21 +00:00)

# %% [markdown]
# # Model Definition
#
# The model will be built with the following architecture:
# **LSTM (3) -> Dense (2) -> Output**

# %%
#Defines Model Architecture
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Bidirectional, Dropout, Input
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Input(shape=(30, 1)), 
    Bidirectional(LSTM(50, dropout=0.3, return_sequences=True)),
    Bidirectional(LSTM(50, dropout=0.3, return_sequences=True)),
    Bidirectional(LSTM(50, dropout=0.3)),
    Dense(32, activation='relu'),
    Dropout(0.5),
    #Dense(64, activation='relu'),
    #Dropout(0.5),
    Dense(7)
])

model.compile(
    loss='mae',
    optimizer=Adam(learning_rate=1e-5),
    metrics=['mse']
)
# Out:
# time: 12.7 s (started: 2024-11-27 14:12:21 +00:00)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional


# Definir EarlyStopping
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10  # Cambiado de 25 a 10
)
# Definir el número de ejemplos que deseas usar
num_samples = 1000

# Obtener índices aleatorios de manera eficiente
indices = np.random.choice(train_X.shape[0], num_samples, replace=False)

# Crear subconjuntos
train_X_subset = train_X[indices]
train_y_subset = train_y[indices]

# Crear un pipeline de datos usando tf.data
train_dataset = tf.data.Dataset.from_tensor_slices((train_X_subset, train_y_subset))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(64).prefetch(tf.data.experimental.AUTOTUNE)

history = model.fit(
    train_dataset,
    validation_data=(val_X, val_y),
    epochs=5,  # Cambiado a 5 épocas
    batch_size=64,  # Cambiado de 4096 a 64
    callbacks=[early_stop],
    verbose=1  # Cambiado a 1 para ver el progreso
)

print("MODEL SUMMARY")
print("==========================")

model.summary()
# Out:
# Epoch 1/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 50s 3s/step - loss: 0.6441 - mse: 0.8491 - val_loss: 0.6504 - val_mse: 0.9562
# Epoch 2/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - loss: 0.6563 - mse: 0.8293 - val_loss: 0.6488 - val_mse: 0.9527
# Epoch 3/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - loss: 0.6343 - mse: 0.8137 - val_loss: 0.6472 - val_mse: 0.9493
# Epoch 4/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - loss: 0.6327 - mse: 0.8235 - val_loss: 0.6456 - val_mse: 0.9457
# Epoch 5/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - loss: 0.6195 - mse: 0.7913 - val_loss: 0.6440 - val_mse: 0.9422
# MODEL SUMMARY
# ==========================
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 30, 100)        │        20,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 30, 100)        │        60,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 100)            │        60,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 435,191 (1.66 MB)
#  Trainable params: 145,063 (566.65 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 290,128 (1.11 MB)
# time: 3min 34s (started: 2024-11-27 14:12:34 +00:00)

# %%
#plots the models training history

fig, axs = plt.subplots(1, 2, figsize=(16,4))

axs[0].plot(history.history['loss'], label='Train')
axs[0].plot(history.history['val_loss'], label='Validation')
axs[0].set_xlabel('Epoch', {'size': 14, 'weight': 'bold'})
axs[0].set_ylabel('MAE Score', {'size': 14, 'weight': 'bold'})
axs[0].set_title('Mean Absolute Error', {'size': 18, 'weight': 'bold'})
axs[0].legend()

axs[1].plot(history.history['mse'], label='Train')
axs[1].plot(history.history['val_mse'], label='Validation')
axs[1].set_xlabel('Epoch', {'size': 14, 'weight': 'bold'})
axs[1].set_ylabel('MSE Score', {'size': 14, 'weight': 'bold'})
axs[1].set_title('Mean Squared Error', {'size': 18, 'weight': 'bold'})
axs[1].legend()

fig.text(0.375, 1.1,"Model Training History", {'size': 25, 'weight': 'bold'})

plt.show()
# Out:
# time: 448 ms (started: 2024-11-27 14:16:09 +00:00)

# %% [markdown]
# # Model Evaluation
#
# The model will be evaluated based on the RSME of AQI predictions and actual AQI values.
# The model predicts AQI values up to 7 days in advance. Each prediction timestep will be analyzed.
# A **successful model will beat a baseline and have an RSME under 20 for all timesteps**.
#
# **Baseline:**
# The baseline model will predict the AQI mean for every value.

# %%
#Rescales data/ predictions back to normal values

train_preds = (model.predict(train_X_subset) * aqi_std) + aqi_mean
val_preds = (model.predict(val_X) * aqi_std) + aqi_mean
test_preds = (model.predict(test_X) * aqi_std) + aqi_mean

train_y_real = train_y  * aqi_std + aqi_mean
val_y_real = val_y  * aqi_std + aqi_mean
test_y_real = test_y  * aqi_std + aqi_mean


train_baseline = np.array([aqi_mean for a in train_y_real[:, 0]])
val_baseline = np.array([aqi_mean for a in val_y_real[:, 0]])
test_baseline = np.array([aqi_mean for a in test_y_real[:, 0]])
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step
# 2317/2317 ━━━━━━━━━━━━━━━━━━━━ 79s 34ms/step
# 2168/2168 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step
# time: 2min 37s (started: 2024-11-27 14:16:09 +00:00)

# %%
from sklearn.metrics import mean_squared_error as mse

#plots training data error
for i in range(7):    
    plt.figure(figsize=(16, 4))
    rsme = round(np.sqrt(mse(train_y_subset[:, i], train_preds[:, i])), 2)
    baseline_rsme = round(np.sqrt(mse(train_y_real[:, i], train_baseline)), 2)
    plt.plot(train_y_real[:, i], color='black', alpha=0.2, label='Actual Value')
    plt.plot(train_preds[:, i], color='blue', alpha=0.2, label='Predicted Value')
    plt.plot(train_baseline, color='black', alpha=0.85, label='Baseline')
    plt.text(-15_000,400, "RMSE: {rsme}".format(rsme=rsme), {'size': 10, 'weight': 'bold'})
    plt.text(-15_000,450, "Baseline RMSE: {rsme}".format(rsme=baseline_rsme), {'size': 10, 'weight': 'bold'})
    plt.title('Predicted vs Actual {day} Day(s) Out'.format(day=i+1), {'size': 14, 'weight': 'bold'})
    plt.legend(loc='upper right')
    if i == 0:
        plt.text(0.15e6, 700, "Training Set Predicted vs Actual", {'size': 35, 'weight': 'bold'})
    plt.show()
# Out:
# time: 5.02 s (started: 2024-11-27 14:18:47 +00:00)

# %%
#plots validation set data
for i in range(7):    
    plt.figure(figsize=(16, 4))
    rsme = round(np.sqrt(mse(val_y_real[:, i], val_preds[:, i])), 2)
    baseline_rsme = round(np.sqrt(mse(val_y_real[:, i], val_baseline)), 2)
    plt.plot(val_y_real[:, i], color='black', alpha=0.2, label='Actual Value')
    plt.plot(val_preds[:, i], color='blue', alpha=0.2, label='Predicted Value')
    plt.plot(val_baseline, color='black', alpha=0.85, label='Baseline')
    plt.text(-100,400, "RMSE: {rsme}".format(rsme=rsme), {'size': 10, 'weight': 'bold'})
    plt.text(-100,450, "Baseline RMSE: {rsme}".format(rsme=baseline_rsme), {'size': 10, 'weight': 'bold'})
    plt.title('Predicted vs Actual {day} Day(s) Out'.format(day=i+1), {'size': 14, 'weight': 'bold'})
    plt.legend(loc='upper right')
    if i == 0:
        plt.text(7_000, 700, "Validation Set Predicted vs Actual", {'size': 35, 'weight': 'bold'})
    plt.show()
# Out:
# time: 3.38 s (started: 2024-11-27 14:18:52 +00:00)

# %%
#plots test data error
for i in range(7):    
    plt.figure(figsize=(16, 4))
    rsme = round(np.sqrt(mse(test_y_real[:, i], test_preds[:, i])), 2)
    baseline_rsme = round(np.sqrt(mse(test_y_real[:, i], test_baseline)), 2)
    plt.plot(test_y_real[:, i], color='black', alpha=0.2, label='Actual Value')
    plt.plot(test_preds[:, i], color='blue', alpha=0.2, label='Predicted Value')
    plt.plot(test_baseline, color='black', alpha=0.85, label='Baseline')
    plt.text(-100,400, "RMSE: {rsme}".format(rsme=rsme), {'size': 10, 'weight': 'bold'})
    plt.text(-100,450, "Baseline RMSE: {rsme}".format(rsme=baseline_rsme), {'size': 10, 'weight': 'bold'})
    plt.title('Predicted vs Actual {day} Day(s) Out'.format(day=i+1), {'size': 14, 'weight': 'bold'})
    plt.legend(loc='right')
    if i == 0:
        plt.text(10_000, 700, "Test Set Predicted vs Actual", {'size': 35, 'weight': 'bold'})
    plt.show()
# Out:
# time: 2.42 s (started: 2024-11-27 14:18:56 +00:00)

# %% [markdown]
# # Conclusion
#
# <ul>
#     <li><strong>AQI levels have been dropping each decade</strong></li>
#     <li><strong>AQI is autocorrelated and can be predicted based on previous values</strong></li>
#     <li><strong>A model with RSME &#60; 20 was successfully created</strong></li>
# </ul>
#
# ### Way Forward
#
# The model created here is acceptable for *OpenAQI.io*'s V1 model. However, there are many ways to improve the predictive performance of future models.
#
# 1. Add weather data to dataset (wind/temperature/precipitation)
# 2. Add locational data to dataset (coordinates/population)
# 3. Increase timestep granularity (instead of daily, find hourly data)
# 4. Tweak model architecture to be aware of all sensors at each timestep (graph neural network)
